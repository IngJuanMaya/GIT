# %% [markdown]
# ## **Herramientas y software para el análisis de datos (Python, R, Excel y SQL).**
#
# 1) ¿Qué necesita un científico de datos y que habilidades le exige el mercado?
# * Conocimiento experto.
#
# * Análisis de datos, se necesita:
#
#       Lenguajes de programación de propósito general.
#
#       Flexibilidad y programación interactiva.
#
#       Herramientas de reporting.
#
#       Potencia de cálculo.
#
#       Comunidades de software.
#
# * Skills de desarrollador.
#
#       Estándares de programación.
#
# 2) ¿A qué se dedica un científico de datos?
#
# * Procesamiento >70% del tiempo -.-
#
# * Modelamiento +- 30% del tiempo.
#
# 3) Uso de lenguajes.
#
# * Estadísticas de uso Python y R.
#
# * ¿Cuál lenguaje elegir? Criterios.
#
# * ¿Cuál veremos en las clases? PYTHON.
#
# 4) Herramientas de desarrollo – principales características.
#
# * Rstudio.
#
# * Jupyther.
#
# *	Spyder.
#
# *	Google Colab.
#
# *	VisualStudio.
#
# *	Servicios Cloud.
#
# *	Uso obligatorio: SQL -> Mysql, PostgreSQl, Oracle, Bigquery, etc.

# %% [markdown]
# # jfjfjf
#
# ## kffkkf
#
# * fkfkfk
#
# 1) **kdkdkdk**

# %%
import numpy as np

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ## 1) ¿Qué necesita un científico de datos y que habilidades le exige el mercado?
#
# * Conocimiento experto.
#     Si o si el equipo del desarrollo-análisis debe tener conocimiento-contexto del negocio o problema. Así se podra visualizar mejor los datos.
#
# * Análisis de datos, se necesita:
#
#       Lenguajes de programación de propósito general (GPL).
#     Ejemplos: Java y Python. (DSL) Lenguajes de proposito especifico seria SQL. ¿Por qué?
#
#       Flexibilidad y programación interactiva (en el sentido de exploración y feedback).
#
#       Herramientas de reporting.
#     Capacidad de generar resultados en el lenguaje del usuario.
#
#       Potencia de cálculo.
#     Manejo de datos masivos (MB, GB, TB). Optimización y rapidez.
#
#       Comunidades de software.
#     Debemos saber de todo, pero cuando no seamos hay que recurrir a foros, doc oficiales, etc.
#
# * Skills de desarrollador.
#       Entender y seleccionar arquitecturas adecuadas (pipelines).
#       Estándares de programación.
#
#
#
# Un ciclo común de desarrollo es:
#
# * Extracción de datos.
#
# * Limpieza de datos.
#
# * Visualización.
#
# * Análisis estadistico y modelado.

# %% [markdown]
# ## Visualización general
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://blogs.iadb.org/gestion-fiscal/es/que-es-la-analitica-de-datos-y-como-puede-contribuir-a-mejorar-el-cumplimiento-tributario-en-america-latina-y-el-caribe/
#
#
# https://www.grupo-novatech.com/como-crear-un-equipo-de-alto-desempeno-para-analitica/

# %% [markdown]
# ## 2) ¿A qué se dedica un científico de datos?
#
# * Procesamiento >70% del tiempo -.-
#
# * Modelamiento +- 30% del tiempo.
#
# ¿Por qué sucede esto?

# %% [markdown]
# 3) Uso de lenguajes.
#
# Estadísticas de uso Python y R.
#
# ![image.png](data:image/png;base64,...)
#
# link: https://www.stackscale.com/es/blog/lenguajes-programacion-mas-populares/
#
#
# ¿Cuál lenguaje elegir? Criterios.
#
# Para un programador, la elección del lenguaje en que ejecutara el desarrollo es similar a legir una herramienta para un trabajo físico, como un martillo, una pala, un cautil, etc. Es decir, hay que elegir bien.
#
# Es muy normal que un análista de datos sea un Poliglota de lenguajes de programación.
#
# Si hay que trabajar con procesamiento de datos se elige uno en particualar. si se debe presentar una interfaz web eligira otro y así para ddiferentes retos.
#
# Python - usado comunmente para desarrollos web, de escritorio o enbebidos.
#
# Java - Usado frecuentemente para desarrollo web, aplicaciones mobiles y de escritorio.
#
# C# - Para aplicaciones mobiles, de esritorio y enbebidos.
#
# Javascrip - unicamente en desarrollo web.
#
# R - es usado en desarrollos para escritorio. Es un lenguaje bastante exendido en el ambito academico.
#
#
# ¿Cuál veremos en las clases? PYTHON y SQL.

# %% [markdown]
# ## 4) Herramientas de desarrollo (Entornos de programación IDEs) – principales características.
#
# Jupyther
#
# Spyder
#
# Google Colab
#
# VisualStudio
#
# Servicios Cloud.
#
# * Microsoft - Azure
#
# * Amazon - AWS
#
# * Google - Google Cloud
#
#
#
# Entendimiento casi que obligatorio de SQL ->ejemplo: Mysql, PostgreSQl, Oracle, Bigquery, etc.

# %% [markdown]
# ## 5) Intalación de PowerBI Desktop
